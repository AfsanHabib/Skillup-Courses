# %% [markdown]
# # Line Charts

# %% [markdown]
# <div style="margin-top: 20px">
#
# <font size = 3>
#
#
# We will learn about a visualization tool namely **Line Chart**, and learn how to create it using Matplotlib.
#
#
# A **line chart** or line graph is a type of chart which displays information as a series of data points called ‘markers’ connected by straight line segments. It is a basic type of  chart common in many fields.
#
# A line chart is often used to visualize a trend in data over intervals of time – a time series – thus the line is often drawn chronologically. In these cases they are known as run charts.
#
#
# Let us look at an example of line chart where we will visualize the gdp of countries in North America.
#
#
# </font>
# </div>

# %% [markdown]
# ## Exploring Datasets with pandas

# %% [markdown]
# pandas is an essential data analysis toolkit for Python. From their [website](https://pandas.pydata.org/):
#
# > pandas is a Python package providing fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python.
#
# The lab relies on pandas for data wrangling, analysis, and visualization. We encourage you to spend some time and familizare yourself with the pandas API Reference: [http://pandas.pydata.org/pandas-docs/stable/api.html.](http://pandas.pydata.org/pandas-docs/stable/api.html)

# %% [markdown]
# ## The Dataset: gdp of Countries in North America (year 1952 - 2007)
#
# The dataset contains the gdp data for the countries in North America. The current version presents data pertaining to 14 countries.
#
# You may access the data [here](https://raw.githubusercontent.com/arpgpt/data-visualization/master/north_america.csv)

# %% [markdown]
# #### Matplotlib
#
# **Matplotlib** is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# To know more about matplotlib library, refer to the link [here](https://matplotlib.org/)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# #### panda Basics
#
# We will now import the **pandas** module.

# %%
import pandas as pd #we can also plot data directly from a Pandas framework

# %%
# Consider the following example:
time = [0, 1, 2, 3]
position = [0, 100, 200, 300]

plt.plot(time, position)
plt.xlabel('Time (hr)')
plt.ylabel('Position (km)')
plt.annotate('label', xy=(1.0,200), color='black')
# Out:
# Text(1.0, 200, 'label')

# %% [markdown]
# This is what a basic line chart looks like.
#
# We will now read our data set.

# %%
df_namerica = pd.read_csv('https://raw.githubusercontent.com/arpgpt/data-visualization/master/north_america.csv', index_col='country')

# %% [markdown]
# - Before plotting, we convert the column headings from a string to integer data type, since they represent numerical values.
# - Extract year from last 4 characters of each column name.
# - The current column names are structured as 'gdpPercap_(year)',
# - so we want to keep the (year) part only for clarity when plotting GDP vs. years
# - To do this we use strip(), which removes from the string the characters stated in the argument
# - This method works on strings, so we call str before strip()

# %%
years = df_namerica.columns.str.strip('gdpPercap_')

df_namerica.columns = years.astype(int) # Convert year values to integers, saving results back to dataframe

# %% [markdown]
# We will now plot a line chart for all the countries in North America

# %%
df_namerica.plot() #default plot 'kind' is line.
plt.ylabel('GDP per capita')
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0, 0.5, 'GDP per capita')

# %% [markdown]
# This plot looks confusing and crowded. Let us clean the data a bit more and plot a line chart after transposing the axis.

# %%
df_namerica.T.plot() 
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %% [markdown]
# This line chart is much more descriptive in nature than the previous one. We can conclude that the United States has consistently better GDP per capita as compared to other countries in the list.
#
# Let us now plot the data for US in a separate line chart. For this we will use ***loc***

# %%
df_namerica.loc["United States"].plot() 
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %% [markdown]
# We can even plot line chart for different countries simulatneously.

# %%
df_namerica.loc['Panama'].plot()  #Plot data for Panama, note that we use loc here and not iloc
df_namerica.loc['Dominican Republic'].plot()  #Plot data for Dominican Republic, note that we use loc here and not iloc
df_namerica.loc['Cuba'].plot()  #Plot data for Cuba, note that we use loc here and not iloc
# Out:
# <AxesSubplot:>

# %% [markdown]
# Clearly, we are clueless as to which line plot belongs to which country. Hence, as a good coding hygiene one should always add legend to the plot to explain characters, symbols, or markings on a document that may be unfamiliar to the reader.

# %%
df_namerica.loc['Panama'].plot()  #Plot data for Panama, note that we use loc here and not iloc
df_namerica.loc['Dominican Republic'].plot()  #Plot data for Dominican Republic, note that we use loc here and not iloc
df_namerica.loc['Cuba'].plot()  #Plot data for Cuba, note that we use loc here and not iloc
plt.legend()  #add legend()

# %% [markdown]
# #### Custom Line Color
#
# To change the line color, use the **‘color’** argument.

# %%
df_namerica.loc["United States"].plot(color='green') 
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %% [markdown]
# You can also add transparency to the color with the **'alpha'** argument (0=transparent, 1=opaque)

# %%
df_namerica.loc["United States"].plot(color='green', alpha=0.4) 
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %% [markdown]
# #### Custom Line Style
#
# You can choose between different line styles with the **'linestyle'** argument.
# A few of the line styles available are:
# - **-**
# - **--**
# - **-.**
# - **:**
#
#
# We will now see how these different line styles look like in a line plot.

# %%
df_namerica.loc["United States"].plot(linestyle='-') #linestyle = 'solid'
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %%
df_namerica.loc["United States"].plot(linestyle='--') #linestyle = 'dashed'
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %%
df_namerica.loc["United States"].plot(linestyle='-.') #linestyle = 'dashdot'
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %%
df_namerica.loc["United States"].plot(linestyle=':') #linestyle = 'dotted'
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %% [markdown]
# #### Custom Line width
#
# You can custom the line width usng the **'linewidth'** argument.

# %%
df_namerica.loc["United States"].plot(linewidth = 5) 
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %% [markdown]
# #### Add annotation in the line plot

# %%
df_namerica.loc["United States"].plot(linewidth = 5) 
plt.ylabel('GDP per capita')
plt.annotate('GDP for USA', xy=(1970,30000), color='black') 
#here xy=() depicts the location of the annotate text
# Out:
# Text(1970, 30000, 'GDP for USA')

# %% [markdown]
# Now we will add the observations on top of each point plotted in the line chart.
# Consider the following example where we plot values generated from two populated lists.

# %%
df = df_namerica.loc["United States"]
df.plot()
df
# Out:
# 1952    13990.48208
# 1957    14847.12712
# 1962    16173.14586
# 1967    19530.36557
# 1972    21806.03594
# 1977    24072.63213
# 1982    25009.55914
# 1987    29884.35041
# 1992    32003.93224
# 1997    35767.43303
# 2002    39097.09955
# 2007    42951.65309
# Name: United States, dtype: float64

# %%
xs = [1,2,3,4,5,6,7,8]
ys = [10,20,30,40,50,60,70,80]
plt.plot(xs,ys,'bo-')
for x,y in zip(xs,ys):
    label = (x,y)
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

# %% [markdown]
# ## Hand-on Practice
#
# Here you will put your knowledge into action:
#
# Access the data set for Europe [here](https://raw.githubusercontent.com/arpgpt/data-visualization/master/gdp_europe.csv) and implement what you learnt in the lab!
#
# Happy Learning!
